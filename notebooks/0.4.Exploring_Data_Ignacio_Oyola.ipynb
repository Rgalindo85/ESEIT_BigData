# %% [markdown]
# # Working with Data

# %% [markdown]
# * Exploring your Data
# * Data Preprocessing
# * Generate good models

# %%
import os, sys
import pandas as pd
import numpy as np
import seaborn as sns
import pandas_gbq
import matplotlib.pyplot as plt

#definir las rutas de los directorios
from pathlib import Path
current_dir=Path('.').resolve()
project_dir=Path(current_dir).parent

# %%
query = """
    SELECT
        * 
     FROM 
        `bigquery-public-data.chicago_taxi_trips.taxi_trips` 
     LIMIT 1000
"""
df=pd.read_gbq(query)
df.head()
# Out:
#                                  unique_key  \
# 0  1635cc78e071c55379ba87d3d275a4f21333d213
# 1  1e3168900f8090e1bab555b15210f6ad701af327
# 2  c620405438b7bfcc6378f885f6aa56d1b8be9369
# 3  c8b56b9c599580efc1e4ffe36ac36cfb7ea85cbd
# 4  c876619a0a2869039533144d7105948e9cfc1951
#
#                                              taxi_id  \
# 0  d2602cb4eab81d9227cd17a415cec4099309d84ff8520c...
# 1  d2602cb4eab81d9227cd17a415cec4099309d84ff8520c...
# 2  d2602cb4eab81d9227cd17a415cec4099309d84ff8520c...
# 3  d2602cb4eab81d9227cd17a415cec4099309d84ff8520c...
# 4  1158f25979ad78fd3dafc867a540ad761b65922c312e61...
#
#        trip_start_timestamp        trip_end_timestamp  trip_seconds  \
# 0 2016-09-22 11:30:00+00:00 2016-09-22 11:45:00+00:00           600
# 1 2016-09-22 11:45:00+00:00 2016-09-22 12:00:00+00:00           960
# 2 2016-09-22 15:00:00+00:00 2016-09-22 15:45:00+00:00          3000
# 3 2016-09-22 17:15:00+00:00 2016-09-22 17:45:00+00:00          2220
# 4 2016-09-19 21:00:00+00:00 2016-09-19 21:30:00+00:00          1560
#
#    trip_miles  pickup_census_tract  dropoff_census_tract  \
# 0         0.8                 <NA>                  <NA>
# 1         7.6                 <NA>                  <NA>
# 2        13.2                 <NA>                  <NA>
# 3        12.2                 <NA>                  <NA>
# 4        15.6                 <NA>                  <NA>
#
#    pickup_community_area  dropoff_community_area  ...  extras  trip_total  \
# 0                   <NA>                    <NA>  ...     0.0        9.25
# 1                   <NA>                    <NA>  ...     0.0       21.50
# 2                   <NA>                    <NA>  ...     0.0       37.00
# 3                   <NA>                    <NA>  ...     4.5       46.58
# 4                   <NA>                    <NA>  ...     4.0       52.40
#
#    payment_type               company  pickup_latitude pickup_longitude  \
# 0   Credit Card  Chicago Independents              NaN              NaN
# 1          Cash  Chicago Independents              NaN              NaN
# 2          Cash  Chicago Independents              NaN              NaN
# 3   Credit Card  Chicago Independents              NaN              NaN
# 4   Credit Card              Sun Taxi              NaN              NaN
#
#   pickup_location  dropoff_latitude  dropoff_longitude dropoff_location
# 0            None               NaN                NaN             None
# 1            None               NaN                NaN             None
# 2            None               NaN                NaN             None
# 3            None               NaN                NaN             None
# 4            None               NaN                NaN             None
#
# [5 rows x 23 columns]

# %%
#get only numeric columns
numerics = ['int16','int32','int64','float16','float32','float64']

num_df= df.select_dtypes(include=numerics)
num_df.head()
# Out:
#    trip_seconds  trip_miles  pickup_census_tract  dropoff_census_tract  \
# 0           600         0.8                 <NA>                  <NA>
# 1           960         7.6                 <NA>                  <NA>
# 2          3000        13.2                 <NA>                  <NA>
# 3          2220        12.2                 <NA>                  <NA>
# 4          1560        15.6                 <NA>                  <NA>
#
#    pickup_community_area  dropoff_community_area   fare  tips  tolls  extras  \
# 0                   <NA>                    <NA>   6.75  2.00    0.0     0.0
# 1                   <NA>                    <NA>  21.50  0.00    0.0     0.0
# 2                   <NA>                    <NA>  37.00  0.00    0.0     0.0
# 3                   <NA>                    <NA>  35.50  6.08    0.0     4.5
# 4                   <NA>                    <NA>  39.25  8.65    0.0     4.0
#
#    trip_total  pickup_latitude  pickup_longitude  dropoff_latitude  \
# 0        9.25              NaN               NaN               NaN
# 1       21.50              NaN               NaN               NaN
# 2       37.00              NaN               NaN               NaN
# 3       46.58              NaN               NaN               NaN
# 4       52.40              NaN               NaN               NaN
#
#    dropoff_longitude
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
num_df.describe()
# Out:
#        trip_seconds   trip_miles pickup_census_tract dropoff_census_tract  \
# count   1000.000000  1000.000000                   0                    0
# mean     827.440000     6.726440                <NA>                 <NA>
# std      803.937998    18.950691                <NA>                 <NA>
# min        0.000000     0.000000                <NA>                 <NA>
# 25%      347.500000     1.000000                <NA>                 <NA>
# 50%      600.000000     1.900000                <NA>                 <NA>
# 75%      960.000000     5.725000                <NA>                 <NA>
# max     6240.000000   195.900000                <NA>                 <NA>
#
#       pickup_community_area dropoff_community_area         fare         tips  \
# count                     0                      0  1000.000000  1000.000000
# mean                   <NA>                   <NA>    13.628910     1.578080
# std                    <NA>                   <NA>    13.689976     2.675334
# min                    <NA>                   <NA>     0.010000     0.000000
# 25%                    <NA>                   <NA>     6.000000     0.000000
# 50%                    <NA>                   <NA>     8.500000     0.000000
# 75%                    <NA>                   <NA>    14.762500     2.000000
# max                    <NA>                   <NA>   145.000000    20.000000
#
#        tolls       extras   trip_total  pickup_latitude  pickup_longitude  \
# count  907.0  1000.000000  1000.000000              0.0               0.0
# mean     0.0     0.970000    16.376990              NaN               NaN
# std      0.0     3.560024    16.965577              NaN               NaN
# min      0.0     0.000000     0.010000              NaN               NaN
# 25%      0.0     0.000000     7.250000              NaN               NaN
# 50%      0.0     0.000000    10.250000              NaN               NaN
# 75%      0.0     1.000000    17.500000              NaN               NaN
# max      0.0    72.000000   217.000000              NaN               NaN
#
#        dropoff_latitude  dropoff_longitude
# count               0.0                0.0
# mean                NaN                NaN
# std                 NaN                NaN
# min                 NaN                NaN
# 25%                 NaN                NaN
# 50%                 NaN                NaN
# 75%                 NaN                NaN
# max                 NaN                NaN

# %% [markdown]
# # One dimensional data

# %%
fig, ax=plt.subplots(ncols=2, nrows=1, figsize=(10, 5))
num_df['trip_seconds'].plot(kind='hist', bins=50, ax=ax[0])
num_df['trip_seconds'].plot(kind='box',           ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# assigning a graph to each ax
sns.boxplot(num_df["trip_seconds"], ax=ax_box)
sns.histplot(data=num_df, x="trip_seconds", bins=30, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

plt.suptitle('taxi trips duration chicago')
ax_hist.grid()


plot_path = os.path.join(project_dir, 'reports', 'plots', 'taxi-trip-duration-chicago')
#f.savefig(plot_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax=plt.subplots(ncols=2, nrows=1, figsize=(10, 5))
num_df['trip_miles'].plot(kind='hist', bins=50, ax=ax[0])
num_df['trip_miles'].plot(kind='box',           ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# assigning a graph to each ax
sns.boxplot(num_df["trip_miles"], ax=ax_box)
sns.histplot(data=num_df, x="trip_miles", bins=30, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

plt.suptitle('taxi trips length chicago')
ax_hist.grid()


plot_path = os.path.join(project_dir, 'reports', 'plots', 'taxi-trip-length-chicago')
#f.savefig(plot_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax=plt.subplots(ncols=2, nrows=1, figsize=(10, 5))
num_df['trip_total'].plot(kind='hist', bins=50, ax=ax[0])
num_df['trip_total'].plot(kind='box',           ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# assigning a graph to each ax
sns.boxplot(num_df["trip_total"], ax=ax_box)
sns.histplot(data=num_df, x="trip_total", bins=30, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

plt.suptitle('taxi trips chicago')
ax_hist.grid()


plot_path = os.path.join(project_dir, 'reports', 'plots', 'taxi-trips-chicago')
#f.savefig(plot_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax=plt.subplots(ncols=2, nrows=1, figsize=(10, 5))
num_df['fare'].plot(kind='hist', bins=50, ax=ax[0])
num_df['fare'].plot(kind='box',           ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# assigning a graph to each ax
sns.boxplot(num_df["fare"], ax=ax_box)
sns.histplot(data=num_df, x="fare", bins=30, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

plt.suptitle('taxi trips fare chicago')
ax_hist.grid()


plot_path = os.path.join(project_dir, 'reports', 'plots', 'taxi-trips-fare-chicago')
#f.savefig(plot_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax=plt.subplots(ncols=2, nrows=1, figsize=(10, 5))
num_df['tips'].plot(kind='hist', bins=50, ax=ax[0])
num_df['tips'].plot(kind='box',           ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# assigning a graph to each ax
sns.boxplot(num_df["tips"], ax=ax_box)
sns.histplot(data=num_df, x="tips", bins=30, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

plt.suptitle('taxi trips tips chicago')
ax_hist.grid()


plot_path = os.path.join(project_dir, 'reports', 'plots', 'taxi-trips-tips-chicago')
#f.savefig(plot_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax=plt.subplots(ncols=2, nrows=1, figsize=(10, 5))
num_df['tolls'].plot(kind='hist', bins=50, ax=ax[0])
num_df['tolls'].plot(kind='box',           ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# assigning a graph to each ax
sns.boxplot(num_df["tolls"], ax=ax_box)
sns.histplot(data=num_df, x="tolls", bins=30, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

plt.suptitle('taxi trips tolls chicago')
ax_hist.grid()


plot_path = os.path.join(project_dir, 'reports', 'plots', 'taxi-trips-tolls-chicago')
#f.savefig(plot_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax=plt.subplots(ncols=2, nrows=1, figsize=(10, 5))
num_df['extras'].plot(kind='hist', bins=50, ax=ax[0])
num_df['extras'].plot(kind='box',           ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# assigning a graph to each ax
sns.boxplot(num_df["extras"], ax=ax_box)
sns.histplot(data=num_df, x="extras", bins=30, ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

plt.suptitle('taxi trips extras chicago')
ax_hist.grid()


plot_path = os.path.join(project_dir, 'reports', 'plots', 'taxi-trips-extras-chicago')
#f.savefig(plot_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Log-Transform

# %%
x = num_df['trip_seconds']
log_x = np.log(x+1)

f, ax=plt.subplots(1,2, figsize=(15,4))

ax[0].hist(x,     bins=30)
ax[1].hist(log_x, bins=30);

# %% [markdown]
# # Two dimensions

# %%
sns.boxplot(x)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='trip_seconds'>

# %%
sns.boxplot(log_x)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='trip_seconds'>

# %%
log_x.describe()
# Out:
# count    1000.000000
# mean        6.101627
# std         1.595560
# min         0.000000
# 25%         5.853610
# 50%         6.398595
# 75%         6.867974
# max         8.738896
# Name: trip_seconds, dtype: float64

# %%
log_x.mean()
# Out:
# 6.101626616629768

# %%
2.78**(log_x.mean())
# Out:
# 512.1480762581558

# %%
np.exp(log_x.mean())
# Out:
# 446.58359990923947

# %%
num_df.plot(kind='scatter', x='trip_seconds', y='trip_miles', alpha=0.3)
plt.xlim(0, 1500)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
x='trip_seconds'
y='trip_miles'
num_df[[x,y]].corr()
# Out:
#               trip_seconds  trip_miles
# trip_seconds      1.000000    0.388041
# trip_miles        0.388041    1.000000

# %%
num_df.plot(kind='scatter', x='trip_seconds', y='trip_total', alpha=0.3)
plt.xlim(0, 1500)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
x1='trip_seconds'
y1='trip_total'
num_df[[x1,y1]].corr()
# Out:
#               trip_seconds  trip_total
# trip_seconds      1.000000    0.777201
# trip_total        0.777201    1.000000

# %%
x2='trip_seconds'
y2='fare'
num_df[[x,y]].corr()
# Out:
#               trip_seconds  trip_miles
# trip_seconds      1.000000    0.388041
# trip_miles        0.388041    1.000000

# %%
num_df.plot(kind='scatter', x='trip_seconds', y='fare', alpha=0.3)
plt.xlim(0, 1500)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
num_df.plot(kind='scatter', x='trip_seconds', y='tips', alpha=0.3)
plt.xlim(0, 1500)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
x3='trip_seconds'
y3='tips'
num_df[[x,y]].corr()
# Out:
#               trip_seconds  trip_miles
# trip_seconds      1.000000    0.388041
# trip_miles        0.388041    1.000000

# %%
num_df.plot(kind='scatter', x='trip_seconds', y='tolls', alpha=0.3)
plt.xlim(0, 1500)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
x4='trip_seconds'
y4='tolls'
num_df[[x,y]].corr()
# Out:
#               trip_seconds  trip_miles
# trip_seconds      1.000000    0.388041
# trip_miles        0.388041    1.000000

# %%
num_df.plot(kind='scatter', x='trip_seconds', y='extras', alpha=0.3)
plt.xlim(0, 1500)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
x5='trip_seconds'
y5='extras'
num_df[[x,y]].corr()
# Out:
#               trip_seconds  trip_miles
# trip_seconds      1.000000    0.388041
# trip_miles        0.388041    1.000000

# %% [markdown]
# # Log Transform

# %%
log_x = np.log(num_df[x] + 1)
log_y = np.log(num_df[y] + 1)
sns.scatterplot(x=log_x, y=log_y, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='trip_seconds', ylabel='trip_miles'>

# %%
log_num_df= pd.DataFrame(
    columns = [x,y]
)

log_num_df[x] = log_x
log_num_df[y] = log_y

log_num_df.corr()
# Out:
#               trip_seconds  trip_miles
# trip_seconds      1.000000    0.543457
# trip_miles        0.543457    1.000000

# %%
log_x1 = np.log(num_df[x1] + 1)
log_y1 = np.log(num_df[y1] + 1)
sns.scatterplot(x=log_x1, y=log_y1, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='trip_seconds', ylabel='trip_total'>

# %%
log_num_df= pd.DataFrame(
    columns = [x1,y1]
)

log_num_df[x1] = log_x1
log_num_df[y1] = log_y1

log_num_df.corr()
# Out:
#               trip_seconds  trip_total
# trip_seconds      1.000000    0.585017
# trip_total        0.585017    1.000000

# %%
log_x2 = np.log(num_df[x2] + 1)
log_y2 = np.log(num_df[y2] + 1)
sns.scatterplot(x=log_x2, y=log_y2, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='trip_seconds', ylabel='fare'>

# %%
log_num_df= pd.DataFrame(
    columns = [x2,y2]
)

log_num_df[x2] = log_x2
log_num_df[y2] = log_y2

log_num_df.corr()
# Out:
#               trip_seconds      fare
# trip_seconds      1.000000  0.603068
# fare              0.603068  1.000000

# %%
log_x3 = np.log(num_df[x3] + 1)
log_y3 = np.log(num_df[y3] + 1)
sns.scatterplot(x=log_x3, y=log_y3, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='trip_seconds', ylabel='tips'>

# %%
log_num_df= pd.DataFrame(
    columns = [x3,y3]
)

log_num_df[x3] = log_x3
log_num_df[y3] = log_y3

log_num_df.corr()
# Out:
#               trip_seconds      tips
# trip_seconds      1.000000  0.259486
# tips              0.259486  1.000000

# %%
log_x4 = np.log(num_df[x4] + 1)
log_y4 = np.log(num_df[y4] + 1)
sns.scatterplot(x=log_x4, y=log_y4, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='trip_seconds', ylabel='tolls'>

# %%
log_num_df= pd.DataFrame(
    columns = [x4,y4]
)

log_num_df[x4] = log_x4
log_num_df[y4] = log_y4

log_num_df.corr()
# Out:
#               trip_seconds  tolls
# trip_seconds           1.0    NaN
# tolls                  NaN    NaN

# %%
log_x5 = np.log(num_df[x5] + 1)
log_y5 = np.log(num_df[y5] + 1)
sns.scatterplot(x=log_x5, y=log_y5, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='trip_seconds', ylabel='extras'>

# %%
log_num_df= pd.DataFrame(
    columns = [x5,y5]
)

log_num_df[x5] = log_x5
log_num_df[y5] = log_y5

log_num_df.corr()
# Out:
#               trip_seconds    extras
# trip_seconds      1.000000  0.219694
# extras            0.219694  1.000000

# %% [markdown]
# # Many Dimensions

# %%
cols= ['trip_total', 'trip_seconds', 'tips', 'fare', 'extras']
sns.pairplot(data=num_df[cols])

# %%
correlations = num_df[cols].corr()

sns.heatmap(correlations, cmap='Reds', annot=True)
# Out:
# <AxesSubplot:>

# %%
num_df.describe()
# Out:
#        trip_seconds   trip_miles pickup_census_tract dropoff_census_tract  \
# count   1000.000000  1000.000000                   0                    0
# mean     827.440000     6.726440                <NA>                 <NA>
# std      803.937998    18.950691                <NA>                 <NA>
# min        0.000000     0.000000                <NA>                 <NA>
# 25%      347.500000     1.000000                <NA>                 <NA>
# 50%      600.000000     1.900000                <NA>                 <NA>
# 75%      960.000000     5.725000                <NA>                 <NA>
# max     6240.000000   195.900000                <NA>                 <NA>
#
#       pickup_community_area dropoff_community_area         fare         tips  \
# count                     0                      0  1000.000000  1000.000000
# mean                   <NA>                   <NA>    13.628910     1.578080
# std                    <NA>                   <NA>    13.689976     2.675334
# min                    <NA>                   <NA>     0.010000     0.000000
# 25%                    <NA>                   <NA>     6.000000     0.000000
# 50%                    <NA>                   <NA>     8.500000     0.000000
# 75%                    <NA>                   <NA>    14.762500     2.000000
# max                    <NA>                   <NA>   145.000000    20.000000
#
#        tolls       extras   trip_total  pickup_latitude  pickup_longitude  \
# count  907.0  1000.000000  1000.000000              0.0               0.0
# mean     0.0     0.970000    16.376990              NaN               NaN
# std      0.0     3.560024    16.965577              NaN               NaN
# min      0.0     0.000000     0.010000              NaN               NaN
# 25%      0.0     0.000000     7.250000              NaN               NaN
# 50%      0.0     0.000000    10.250000              NaN               NaN
# 75%      0.0     1.000000    17.500000              NaN               NaN
# max      0.0    72.000000   217.000000              NaN               NaN
#
#        dropoff_latitude  dropoff_longitude
# count               0.0                0.0
# mean                NaN                NaN
# std                 NaN                NaN
# min                 NaN                NaN
# 25%                 NaN                NaN
# 50%                 NaN                NaN
# 75%                 NaN                NaN
# max                 NaN                NaN

# %%
a='trip_seconds'
b='trip_miles'
c='trip_total'
d= 'tips'
e= 'fare'
f= 'extras'
num_df[[a,b,c,d,e,f]]
num_df[[a,b,c,d,e,f]].corr()

log_num_df = pd.DataFrame(
    columns=[a,b,c,d,e,f]
)

log_a = np.log(num_df[[a]]+1)
log_b = np.log(num_df[[b]]+1)
log_c = np.log(num_df[[c]]+1)
log_d = np.log(num_df[[d]]+1)
log_e = np.log(num_df[[e]]+1)
log_f = np.log(num_df[[f]]+1)


log_num_df[a] = log_a
log_num_df[b] = log_b
log_num_df[c] = log_c
log_num_df[d] = log_d
log_num_df[e] = log_e
log_num_df[f] = log_f
log_num_df.corr()
# Out:
#             trip_miles  trip_total      tips      fare    extras
# trip_miles    1.000000    0.702480  0.230533  0.741938  0.344184
# trip_total    0.702480    1.000000  0.516821  0.959970  0.476833
# tips          0.230533    0.516821  1.000000  0.369492  0.235966
# fare          0.741938    0.959970  0.369492  1.000000  0.372694
# extras        0.344184    0.476833  0.235966  0.372694  1.000000

# %%
cols= ['trip_total', 'trip_seconds', 'trip_miles','tips', 'fare', 'extras']
sns.pairplot(data=log_num_df[cols])

# %%
correlations = log_num_df[cols].corr()

sns.heatmap(correlations, cmap='Purples', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating Data

# %%
x =     num_df['trip_seconds']
x_min = x.min()
x_max = x.max()

x_mean = x.mean()
x_std  = x.std()

x_min_max_scaled = (x-x_min)/(x_max - x_min) #MinMaxScaler
x_std_scaled   = (x-x_mean)/x_std

plt.hist(x_min_max_scaled, bins=30, label ='MinMax',   histtype='step', lw=2)
plt.hist(x_std_scaled,     bins=30, label ='Standard', histtype='step', lw=3);

plt.legend(title='Scaling method')

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
minmax_scaler = MinMaxScaler().fit(num_df[cols])
data_min_max_scaled = minmax_scaler.transform(num_df[cols])

# %%
num_df[cols].values
# Out:
# array([[9.25, 600, 0.8, 2.0, 6.75, 0.0],
#        [21.5, 960, 7.6, 0.0, 21.5, 0.0],
#        [37.0, 3000, 13.2, 0.0, 37.0, 0.0],
#        ...,
#        [23.3, 1260, 6.0, 3.8, 19.0, 0.0],
#        [9.25, 720, 1.7, 0.0, 9.25, 0.0],
#        [16.25, 960, 5.4, 0.0, 16.25, 0.0]], dtype=object)

# %%
data_min_max_scaled
# Out:
# array([[0.04258261, 0.09615385, 0.00408372, 0.1       , 0.04648596,
#         0.        ],
#        [0.09903682, 0.15384615, 0.0387953 , 0.        , 0.14821712,
#         0.        ],
#        [0.17046869, 0.48076923, 0.06738132, 0.        , 0.25512104,
#         0.        ],
#        ...,
#        [0.10733214, 0.20192308, 0.03062787, 0.19      , 0.13097455,
#         0.        ],
#        [0.04258261, 0.11538462, 0.0086779 , 0.        , 0.06372853,
#         0.        ],
#        [0.07484216, 0.15384615, 0.02756508, 0.        , 0.11200772,
#         0.        ]])

# %%
num_df_minmax_scaled = pd.DataFrame(
    columns = num_df[cols].columns,
    data    = data_min_max_scaled
)
num_df_minmax_scaled.head()
# Out:
#    trip_total  trip_seconds  trip_miles    tips      fare    extras
# 0    0.042583      0.096154    0.004084  0.1000  0.046486  0.000000
# 1    0.099037      0.153846    0.038795  0.0000  0.148217  0.000000
# 2    0.170469      0.480769    0.067381  0.0000  0.255121  0.000000
# 3    0.214618      0.355769    0.062277  0.3040  0.244776  0.062500
# 4    0.241440      0.250000    0.079632  0.4325  0.270639  0.055556

# %%
num_df_minmax_scaled.describe()
# Out:
#         trip_total  trip_seconds   trip_miles         tips         fare  \
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.075427      0.132603     0.034336     0.078904     0.093930
# std       0.078186      0.128836     0.096737     0.133767     0.094420
# min       0.000000      0.000000     0.000000     0.000000     0.000000
# 25%       0.033366      0.055689     0.005105     0.000000     0.041313
# 50%       0.047191      0.096154     0.009699     0.000000     0.058556
# 75%       0.080603      0.153846     0.029224     0.100000     0.101748
# max       1.000000      1.000000     1.000000     1.000000     1.000000
#
#             extras
# count  1000.000000
# mean      0.013472
# std       0.049445
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.013889
# max       1.000000

# %%
x =     num_df['trip_miles']
x_min = x.min()
x_max = x.max()

x_mean = x.mean()
x_std  = x.std()

x_min_max_scaled = (x-x_min)/(x_max - x_min) #MinMaxScaler
x_std_scaled   = (x-x_mean)/x_std

plt.hist(x_min_max_scaled, bins=30, label ='MinMax',   histtype='step', lw=2)
plt.hist(x_std_scaled,     bins=30, label ='Standard', histtype='step', lw=3);

plt.legend(title='Scaling method')

# %%
cols= ['trip_total', 'trip_seconds', 'trip_miles','tips', 'fare', 'extras']
sns.pairplot(data=num_df_minmax_scaled[cols])

# %%
correlations = num_df_minmax_scaled[cols].corr()

sns.heatmap(correlations, cmap='Greens', annot=True)
# Out:
# <AxesSubplot:>
